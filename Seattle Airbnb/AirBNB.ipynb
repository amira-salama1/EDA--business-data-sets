# %% [markdown]
# # importing libraries for EDA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sb

# %%
df_listing = pd.read_csv(r'...Datasets\listings.csv')

# %%
df_listing.head()
# Out:
#         id                           listing_url       scrape_id last_scraped  \
# 0   241032   https://www.airbnb.com/rooms/241032  20160104002432   2016-01-04
# 1   953595   https://www.airbnb.com/rooms/953595  20160104002432   2016-01-04
# 2  3308979  https://www.airbnb.com/rooms/3308979  20160104002432   2016-01-04
# 3  7421966  https://www.airbnb.com/rooms/7421966  20160104002432   2016-01-04
# 4   278830   https://www.airbnb.com/rooms/278830  20160104002432   2016-01-04
#
#                                   name  \
# 0         Stylish Queen Anne Apartment
# 1   Bright & Airy Queen Anne Apartment
# 2  New Modern House-Amazing water view
# 3                   Queen Anne Chateau
# 4       Charming craftsman 3 bdm house
#
#                                              summary  \
# 0                                                NaN
# 1  Chemically sensitive? We've removed the irrita...
# 2  New modern house built in 2013.  Spectacular s...
# ...

# %%
df_listing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3818 entries, 0 to 3817
# Data columns (total 92 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                3818 non-null   int64
#  1   listing_url                       3818 non-null   object
#  2   scrape_id                         3818 non-null   int64
#  3   last_scraped                      3818 non-null   object
#  4   name                              3818 non-null   object
#  5   summary                           3641 non-null   object
#  6   space                             3249 non-null   object
#  7   description                       3818 non-null   object
#  8   experiences_offered               3818 non-null   object
#  9   neighborhood_overview             2786 non-null   object
#  10  notes                             2212 non-null   object
# ...

# %%
pd.options.display.max_rows=100
df_listing.isnull().sum()
# Out:
# id                                     0
# listing_url                            0
# scrape_id                              0
# last_scraped                           0
# name                                   0
# summary                              177
# space                                569
# description                            0
# experiences_offered                    0
# neighborhood_overview               1032
# notes                               1606
# transit                              934
# thumbnail_url                        320
# medium_url                           320
# picture_url                            0
# xl_picture_url                       320
# host_id                                0
# host_url                               0
# host_name                              2
# host_since                             2
# host_location                          8
# host_about                           859
# host_response_time                   523
# ...

# %%
import pandas_profiling
from pandas_profiling import ProfileReport

# %%
profile = ProfileReport (df_listing, title='AirBnb Report' )

# %%
profile.to_file('AirBnb Report.html')
# Out:
# ...
# C:\Users\Amira\anaconda3\lib\site-packages\matplotlib\textpath.py:84: RuntimeWarning: Glyph 35199 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# C:\Users\Amira\anaconda3\lib\site-packages\matplotlib\textpath.py:84: RuntimeWarning: Glyph 38597 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# C:\Users\Amira\anaconda3\lib\site-packages\matplotlib\textpath.py:84: RuntimeWarning: Glyph 22270 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# C:\Users\Amira\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 35199 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Amira\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 38597 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
df_listing.review_scores_rating.value_counts()
# Out:
# 100.0    781
# 98.0     292
# 96.0     278
# 97.0     266
# 95.0     260
# 94.0     198
# 93.0     184
# 99.0     146
# 90.0     138
# 80.0     111
# 92.0     105
# 91.0      97
# 87.0      55
# 89.0      53
# 88.0      47
# 85.0      24
# 84.0      23
# 86.0      17
# 83.0      13
# 60.0      12
# 82.0      10
# 70.0       8
# 73.0       7
# 76.0       5
# 72.0       4
# 78.0       4
# 77.0       4
# 40.0       4
# 75.0       3
# 71.0       3
# 81.0       3
# 68.0       2
# 74.0       2
# 67.0       2
# 79.0       2
# 66.0       2
# 64.0       1
# 20.0       1
# 53.0       1
# 65.0       1
# 55.0       1
# 57.0       1
# Name: review_scores_rating, dtype: int64

# %%
pd.options.display.float_format= "{:.3f}".format
pd.options.display.max_columns=92
df_listing.describe()
# Out:
#                 id          scrape_id      host_id  host_listings_count  \
# count     3818.000           3818.000     3818.000             3816.000
# mean   5550111.419 20160104002432.000 15785555.108                7.158
# std    2962660.479              0.000 14583815.275               28.628
# min       3335.000 20160104002432.000     4193.000                1.000
# 25%    3258256.250 20160104002432.000  3275204.000                1.000
# 50%    6118244.500 20160104002432.000 10558142.000                1.000
# 75%    8035126.750 20160104002432.000 25903093.250                3.000
# max   10340165.000 20160104002432.000 53208610.000              502.000
#
#        host_total_listings_count  latitude  longitude  accommodates  \
# count                   3816.000  3818.000   3818.000      3818.000
# mean                       7.158    47.629   -122.333         3.349
# std                       28.628     0.043      0.032         1.978
# ...

# %%
df_listing.describe(include='object')
# Out:
#                                  listing_url last_scraped  \
# count                                   3818         3818
# unique                                  3818            1
# top     https://www.airbnb.com/rooms/8578490   2016-01-04
# freq                                       1         3818
#
#                           name  \
# count                     3818
# unique                    3792
# top     Capitol Hill Apartment
# freq                         3
#
#                                                   summary  \
# count                                                3641
# unique                                               3478
# top     This is a modern fully-furnished studio apartm...
# freq                                                   15
#
#                                                     space  \
# count                                                3249
# unique                                               3119
# ...

# %%
df_listing.maximum_nights.value_counts()
# Out:
# 1125      2453
# 30         183
# 365        148
# 14         123
# 7          108
# 90          85
# 60          69
# 10          58
# 180         55
# 29          51
# 28          47
# 21          39
# 15          38
# 5           38
# 31          32
# 3           29
# 6           26
# 4           24
# 120         20
# 20          17
# 730         16
# 13           9
# 9            9
# 45           8
# 100          8
# 2            8
# 8            7
# 27           6
# 35           6
# 32           5
# 22           5
# 16           5
# 200          5
# 360          5
# 1            5
# 25           5
# 150          4
# 65           4
# 11           4
# 40           4
# 99           3
# 12           3
# 24           3
# 93           3
# 50           3
# 26           3
# 1000         2
# 125          2
# 183          2
# 18           2
# 270          2
# 23           2
# 33           2
# 95           1
# 91           1
# 999          1
# 400          1
# 352          1
# ...

# %%
df_listing.experiences_offered.value_counts()
# Out:
# none    3818
# Name: experiences_offered, dtype: int64

# %%
sb.set_style("whitegrid")
sb.set_style("ticks", {"xtick.major.size":4, "ytick.major.size": 4})

# %%
df_listing['property_type'].value_counts()
# Out:
# House              1733
# Apartment          1708
# Townhouse           118
# Condominium          91
# Loft                 40
# Bed & Breakfast      37
# Other                22
# Cabin                21
# Camper/RV            13
# Bungalow             13
# Boat                  8
# Tent                  5
# Treehouse             3
# Chalet                2
# Dorm                  2
# Yurt                  1
# Name: property_type, dtype: int64

# %%
df_listing.neighbourhood_group_cleansed.value_counts()
# Out:
# Other neighborhoods    794
# Capitol Hill           567
# Downtown               530
# Central Area           369
# Queen Anne             295
# Ballard                230
# West Seattle           203
# Rainier Valley         159
# University District    122
# Beacon Hill            118
# Cascade                 89
# Northgate               80
# Delridge                79
# Lake City               67
# Magnolia                61
# Seward Park             44
# Interbay                11
# Name: neighbourhood_group_cleansed, dtype: int64

# %%
#Striping $ from columns to change into numerical type instead of object
col = ['price', 'weekly_price', 'monthly_price', 'security_deposit','cleaning_fee']
df_listing[col] = df_listing[col].apply(lambda x: x.str.strip('$'))

# %%
#Test
df_listing.price.value_counts()
# Out:
# 150.00    162
# 100.00    159
# 75.00     118
# 95.00     110
# 99.00     110
#          ...
# 172.00      1
# 113.00      1
# 26.00       1
# 131.00      1
# 287.00      1
# Name: price, Length: 273, dtype: int64

# %%
df_listing[col] = df_listing[col].apply(lambda x: x.str.replace(',',''))

# %%
df_listing.weekly_price.value_counts()
# Out:
# 500.00     94
# 600.00     85
# 1000.00    70
# 450.00     68
# 700.00     62
#            ..
# 863.00      1
# 175.00      1
# 855.00      1
# 548.00      1
# 6300.00     1
# Name: weekly_price, Length: 395, dtype: int64

# %%
#changing prices columns into float type 
df_listing[col] = df_listing[col].astype(float)

# %%
sb.countplot(x='room_type',hue='host_is_superhost' ,data=df_listing)

# %%
sb.countplot(x="host_is_superhost", data=df_listing)
print(df_listing.host_is_superhost.value_counts())
# Out:
# f    3038
# t     778
# Name: host_is_superhost, dtype: int64

# %%
rcParams['figure.figsize']=8,6
df_listing.review_scores_rating.hist();

# %%
df_listing.price.hist();

# %%
df_listing.to_csv('df_listing.csv', index=False)
